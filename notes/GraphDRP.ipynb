# %%
# !pip -q uninstall -y torch torchvision torchaudio torch-geometric torch_scatter torch_sparse torch_cluster torch_spline_conv pyg-lib rdkit rdkit-pypi || true
# Out:
# WARNING: Skipping torch-geometric as it is not installed.
# WARNING: Skipping torch_scatter as it is not installed.
# WARNING: Skipping torch_sparse as it is not installed.
# WARNING: Skipping torch_cluster as it is not installed.
# WARNING: Skipping torch_spline_conv as it is not installed.
# WARNING: Skipping pyg-lib as it is not installed.
# WARNING: Skipping rdkit as it is not installed.
# WARNING: Skipping rdkit-pypi as it is not installed.

# %%
# %%bash
# set -e
# cd /content
# curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj bin/micromamba
# Out:
# bin/micromamba

# %%
# %%bash
# set -e
# export MAMBA_ROOT_PREFIX=/content/micromamba
#
# # αν δεν υπάρχει env, απλά θα το αγνοήσει
# /content/bin/micromamba env remove -n gnn -y || true
#
# /content/bin/micromamba create -y -n gnn \
#   -c conda-forge -c pytorch -c nvidia \
#   python=3.10 \
#   numpy pandas scipy matplotlib \
#   rdkit \
#   pytorch torchvision torchaudio pytorch-cuda=12.1 \
#   pytorch_geometric
# Out:
# Transaction
#
#   Prefix: /content/micromamba/envs/gnn
#
#   Updating specs:
#
#    - python=3.10
#    - numpy
#    - pandas
#    - scipy
#    - matplotlib
#    - rdkit
#    - pytorch
#    - torchvision
#    - torchaudio
#    - pytorch-cuda=12.1
#    - pytorch_geometric
#
#
#   Package                                      Version  Build                       Channel          Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ───────────────────────────────────────────────────────────────────────────────────────────────────────────
#
#   + _openmp_mutex                                  4.5  7_kmp_llvm                  conda-forge       8kB
#   + aiohappyeyeballs                             2.6.1  pyhd8ed1ab_0                conda-forge      20kB
#   + aiohttp                                     3.13.3  py310h31b6992_0             conda-forge     892kB
# ...

# %%
! /content/bin/micromamba run -n gnn python -c "import torch; import torch_geometric; from rdkit import rdBase; import numpy,pandas,scipy,matplotlib; print('torch',torch.__version__); print('cuda',torch.version.cuda); print('cuda_available',torch.cuda.is_available()); print('pyg',torch_geometric.__version__); print('rdkit',rdBase.rdkitVersion)"
# Out:
# critical libmamba The given prefix does not exist: "/root/.local/share/mamba/envs/gnn"

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn python -c "import torch; import torch_geometric; from rdkit import rdBase; print('torch', torch.__version__); print('cuda', torch.version.cuda); print('cuda_available', torch.cuda.is_available()); print('pyg', torch_geometric.__version__); print('rdkit', rdBase.rdkitVersion)"
# Out:
# torch 2.9.1
# cuda None
# cuda_available False
# pyg 2.7.0
# rdkit 2025.09.4

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba install -y -n gnn -c pytorch -c nvidia pytorch-cuda=12.1
# Out:
# pytorch/linux-64                                            Using cache
# pytorch/noarch                                              Using cache
# nvidia/linux-64                                             Using cache
# nvidia/noarch                                               Using cache
#
# Pinned packages:
#
#   - python=3.10
#
#
# Transaction
#
#   Prefix: /content/micromamba/envs/gnn
#
#   All requested packages already installed
#
#
# Transaction starting
# [+] 0.0s
#
# Transaction finished

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn python -c "import torch; print('torch', torch.__version__); print('cuda', torch.version.cuda); print('cuda_available', torch.cuda.is_available())"
# Out:
# torch 2.9.1
# cuda None
# cuda_available False

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba env remove -n gnn -y
# Out:
# Transaction
#
#   Prefix: /content/micromamba/envs/gnn
#
#   Removing specs:
#
#    - _openmp_mutex
#    - aiohappyeyeballs
#    - aiohttp
#    - aiosignal
#    - alsa-lib
#    - aom
#    - async-timeout
#    - attr
#    - attrs
#    - backports.zstd
#    - brotli
#    - brotli-bin
#    - brotli-python
#    - bzip2
#    - ca-certificates
#    - cairo
#    - certifi
#    - charset-normalizer
#    - colorama
#    - contourpy
#    - cpython
#    - cuda-cudart
#    - cuda-cudart_linux-64
#    - cuda-cupti
#    - cuda-libraries
#    - cuda-nvrtc
#    - cuda-nvtx
#    - cuda-opencl
#    - cuda-runtime
#    - cuda-version
#    - cycler
#    - cyrus-sasl
#    - dav1d
#    - dbus
#    - double-conversion
#    - ffmpeg
#    - filelock
#    - fmt
#    - font-ttf-dejavu-sans-mono
#    - font-ttf-inconsolata
#    - font-ttf-source-code-pro
#    - font-ttf-ubuntu
#    - fontconfig
#    - fonts-conda-ecosystem
#    - fonts-conda-forge
#    - fonttools
#    - freetype
#    - freetype-py
# ...

# %%
# %%bash
# set -e
# export MAMBA_ROOT_PREFIX=/content/micromamba
#
# /content/bin/micromamba create -y -n gnn \
#   -c pytorch -c nvidia -c conda-forge \
#   python=3.10 \
#   numpy pandas scipy matplotlib \
#   rdkit \
#   pytorch torchvision torchaudio pytorch-cuda=12.1 \
#   pytorch_geometric
# Out:
# pytorch/linux-64                                            Using cache
# pytorch/noarch                                              Using cache
# nvidia/linux-64                                             Using cache
# nvidia/noarch                                               Using cache
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
#
#
# Transaction
#
#   Prefix: /content/micromamba/envs/gnn
#
#   Updating specs:
#
#    - python=3.10
#    - numpy
#    - pandas
#    - scipy
#    - matplotlib
#    - rdkit
#    - pytorch
#    - torchvision
#    - torchaudio
#    - pytorch-cuda=12.1
#    - pytorch_geometric
#
#
#   Package                           Version  Build                         Channel           Size
# ───────────────────────────────────────────────────────────────────────────────────────────────────
#   Install:
# ...

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn python -c "import torch; print('torch', torch.__version__); print('cuda', torch.version.cuda); print('cuda_available', torch.cuda.is_available()); import torch_geometric; from rdkit import rdBase; print('pyg', torch_geometric.__version__); print('rdkit', rdBase.rdkitVersion)"
# Out:
# torch 2.5.1
# cuda 12.1
# cuda_available True
# pyg 2.7.0
# rdkit 2025.03.6

# %%
# %cd /content
# !git clone https://github.com/hauldhut/GraphDRP.git
# %cd /content/GraphDRP/GraphDRP
# !ls -la
# Out:
# /content
# Cloning into 'GraphDRP'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (14/14), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 31 (delta 6), reused 6 (delta 6), pack-reused 17 (from 1)
# Receiving objects: 100% (31/31), 29.73 MiB | 13.74 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# [Errno 2] No such file or directory: '/content/GraphDRP/GraphDRP'
# /content
# total 28
# drwxr-xr-x 1 root root 4096 Jan 26 10:48 .
# drwxr-xr-x 1 root root 4096 Jan 26 10:32 ..
# drwxr-xr-x 2 root root 4096 Jan 26 10:38 bin
# drwxr-xr-x 4 root root 4096 Dec  9 14:41 .config
# drwxr-xr-x 5 root root 4096 Jan 26 10:48 GraphDRP
# drwxr-xr-x 4 root root 4096 Jan 26 10:38 micromamba
# drwxr-xr-x 1 root root 4096 Dec  9 14:42 sample_data

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn pip -q install pubchempy

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn pip install -q h5py

# %%
# !MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn python -c "import h5py; print('h5py OK', h5py.__version__)"
# Out:
# h5py OK 3.15.1

# %%
# !MPLBACKEND=Agg MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn \
python preprocess.py --choice 0
# Out:
# Streaming output truncated to the last 5000 lines.
# Converting SMILES to graph: 14107/19105
# Converting SMILES to graph: 14108/19105
# Converting SMILES to graph: 14109/19105
# Converting SMILES to graph: 14110/19105
# Converting SMILES to graph: 14111/19105
# Converting SMILES to graph: 14112/19105
# Converting SMILES to graph: 14113/19105
# Converting SMILES to graph: 14114/19105
# Converting SMILES to graph: 14115/19105
# Converting SMILES to graph: 14116/19105
# Converting SMILES to graph: 14117/19105
# Converting SMILES to graph: 14118/19105
# Converting SMILES to graph: 14119/19105
# Converting SMILES to graph: 14120/19105
# Converting SMILES to graph: 14121/19105
# Converting SMILES to graph: 14122/19105
# Converting SMILES to graph: 14123/19105
# Converting SMILES to graph: 14124/19105
# Converting SMILES to graph: 14125/19105
# Converting SMILES to graph: 14126/19105
# Converting SMILES to graph: 14127/19105
# Converting SMILES to graph: 14128/19105
# ...

# %%
# !ls -la data/processed | head
# Out:
# total 2617512
# drwxr-xr-x 2 root root       4096 Jan 26 11:07 .
# drwxr-xr-x 3 root root       4096 Jan 26 11:05 ..
# -rw-r--r-- 1 root root  267514380 Jan 26 11:07 GDSC_test_mix.pt
# -rw-r--r-- 1 root root 2144143002 Jan 26 11:07 GDSC_train_mix.pt
# -rw-r--r-- 1 root root  268654142 Jan 26 11:07 GDSC_val_mix.pt

# %%
# !MPLBACKEND=Agg MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn python training.py --help | head -n 160
# Out:
# usage: training.py [-h] [--model MODEL] [--train_batch TRAIN_BATCH]
#                    [--val_batch VAL_BATCH] [--test_batch TEST_BATCH] [--lr LR]
#                    [--num_epoch NUM_EPOCH] [--log_interval LOG_INTERVAL]
#                    [--cuda_name CUDA_NAME]
#
# train model
#
# options:
#   -h, --help            show this help message and exit
#   --model MODEL         0: GINConvNet, 1: GATNet, 2: GAT_GCN, 3: GCNNet
#   --train_batch TRAIN_BATCH
#                         Batch size training set
#   --val_batch VAL_BATCH
#                         Batch size validation set
#   --test_batch TEST_BATCH
#                         Batch size test set
#   --lr LR               Learning rate
#   --num_epoch NUM_EPOCH
#                         Number of epoch
#   --log_interval LOG_INTERVAL
#                         Log interval
#   --cuda_name CUDA_NAME
#                         Cuda

# %%
# !MPLBACKEND=Agg MAMBA_ROOT_PREFIX=/content/micromamba /content/bin/micromamba run -n gnn \
python /content/GraphDRP/training.py \
  --model 0 \
  --train_batch 1024 --val_batch 1024 --test_batch 1024 \
  --lr 0.0001 --num_epoch 300 \
  --log_interval 20 \
  --cuda_name "cuda:0" \
  | tee /content/GIN_GDSC_mixed.log
# Out:
# /content/GraphDRP/utils.py:22: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   self.data, self.slices = torch.load(self.processed_paths[0])
# ...

# %%
import pandas as pd

results = pd.DataFrame({
    "Model": ["GINConvNet"],
    "RMSE": [0.0249],
    "Pearson": [0.9309]
})

results.to_csv("graphdrp_results.csv", index=False)
results
# Out:
#         Model    RMSE  Pearson
# 0  GINConvNet  0.0249   0.9309

# %%
import matplotlib.pyplot as plt

models = ["GIN"]
rmse = [0.0249]
pearson = [0.9309]

plt.figure(figsize=(6,4))
plt.bar(models, pearson)
plt.ylabel("Pearson Correlation")
plt.title("GraphDRP – Mixed Test (GDSC)")
plt.ylim(0.85, 1.0)
plt.savefig("graphdrp_pearson.png", dpi=300)
plt.show()

# %%
# !ls /content
# Out:
# bin		    GraphDRP		  graphdrp_results.csv	sample_data
# GIN_GDSC_mixed.log  graphdrp_pearson.png  micromamba

# %%
# !ls /content/GraphDRP
# Out:
# data	 model_GINConvNet_GDSC.model  preprocess.py  saliancy_map.py  utils.py
# LICENSE  models			      README.md      training.py

# %%
# !ls -la /content/GraphDRP/data | head -n 50
# Out:
# total 117176
# drwxr-xr-x 2 root root     4096 Jan 26 10:48 .
# drwxr-xr-x 6 root root     4096 Jan 26 11:00 ..
# -rwxr-xr-x 1 root root    58144 Jan 26 10:48 Cell_list.csv
# -rwxr-xr-x 1 root root    18464 Jan 26 10:48 Druglist.csv
# -rwxr-xr-x 1 root root    34013 Jan 26 10:48 drug_smiles.csv
# -rwxr-xr-x 1 root root    22939 Jan 26 10:48 Feature_listTue Oct 31 03_03_25 2017.csv
# -rwxr-xr-x 1 root root 51399424 Jan 26 10:48 PANCANCER_ANOVA_Tue Oct 31 03_00_59 2017.csv
# -rwxr-xr-x 1 root root 42711365 Jan 26 10:48 PANCANCER_Genetic_feature.csv
# -rwxr-xr-x 1 root root 25523554 Jan 26 10:48 PANCANCER_IC.csv
# -rwxr-xr-x 1 root root   191149 Jan 26 10:48 small_molecule.csv
# -rwxr-xr-x 1 root root      394 Jan 26 10:48 unknow_drug_by_pychem.csv

# %%
# %cd /content/GraphDRP
# !pwd
# !ls -la data/PANCANCER_IC.csv
# Out:
# /content/GraphDRP
# /content/GraphDRP
# -rwxr-xr-x 1 root root 25523554 Jan 26 10:48 data/PANCANCER_IC.csv
